# %%
import os
import torch
from transformers import MaskFormerFeatureExtractor, MaskFormerForInstanceSegmentation
from PIL import Image
import numpy as np
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")
# Check if a GPU is available and set the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load MaskFormer fine-tuned on COCO panoptic segmentation
feature_extractor = MaskFormerFeatureExtractor.from_pretrained("facebook/maskformer-swin-small-coco")
model = MaskFormerForInstanceSegmentation.from_pretrained("facebook/maskformer-swin-small-coco").to(device)

# Function to generate and save mask for a given image
def generate_and_save_mask(image_path, save_path):
    try:
        image = Image.open(image_path).convert("RGB")
        inputs = feature_extractor(images=image, return_tensors="pt").to(device)
        outputs = model(**inputs)
        result = feature_extractor.post_process_panoptic_segmentation(outputs, target_sizes=[image.size[::-1]])[0]
        predicted_panoptic_map = result["segmentation"].detach().cpu().numpy()

        # Convert segmentation map to an image
        segmentation_image = Image.fromarray((predicted_panoptic_map * 255).astype(np.uint8))

        # Save the segmentation image
        segmentation_image.save(save_path)
    except (OSError, ValueError) as e:
        print(f"Skipping {image_path} due to error: {e}")

# Function to process a dataset folder (train, val, test)
def process_dataset_folder(data_folder, output_folder):
    categories = ["fractured", "not fractured"]
    for category in categories:
        input_dir = os.path.join(data_folder, category)
        output_dir = os.path.join(output_folder, category)
        os.makedirs(output_dir, exist_ok=True)

        file_list = [f for f in os.listdir(input_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

        for filename in tqdm(file_list, desc=f"Processing {category} images"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            # Check if the mask already exists
            if not os.path.exists(output_path):
                generate_and_save_mask(input_path, output_path)
            else:
                tqdm.write(f"Mask already exists for {filename}, skipping generation.")

# Paths to your dataset folders
dataset_root = "./Bone_Fracture_Binary_Classification1"
train_folder = os.path.join(dataset_root, "train")
val_folder = os.path.join(dataset_root, "val")
test_folder = os.path.join(dataset_root, "test")

# Paths to the output mask folders
output_root = "./Bone_Fracture_dataset_mask"
train_output_folder = os.path.join(output_root, "train")
val_output_folder = os.path.join(output_root, "val")
test_output_folder = os.path.join(output_root, "test")

# Process each dataset folder
process_dataset_folder(train_folder, train_output_folder)
process_dataset_folder(val_folder, val_output_folder)
process_dataset_folder(test_folder, test_output_folder)

print("Mask generation complete.")
# Out:
# Processing fractured images:   1%|          | 47/4602 [00:00<00:19, 231.65it/s]
# Mask already exists for a6980144fa36a4b20737df405b98b51a (1).jpg, skipping generation.
# Mask already exists for 83-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 89-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 8-rotated2-rotated2.jpg, skipping generation.
# Mask already exists for 96-rotated1-rotated2-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 9-rotated3-rotated2-rotated1 (1).jpg, skipping generation.
# Mask already exists for 6-rotated2-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 91-rotated3-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 7-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 92-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 91-rotated1-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 89-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 80-rotated3-rotated1-rotated1 (1).jpg, skipping generation.
# Mask already exists for 87-rotated1-rotated3-rotated1.jpg, skipping generation.
# Mask already exists for 4-rotated2-rotated3-rotated2.jpg, skipping generation.
# Mask already exists for 83-rotated2-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 87-rotated2-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 5-rotated1-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 5-rotated2-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 91-rotated1-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 6-rotated2-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 8-rotated3-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 89-rotated3-rotated3.jpg, skipping generation.
# Mask already exists for 89-rotated1-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 97-rotated2-rotated3-rotated3.jpg, skipping generation.
# Mask already exists for 88-rotated3-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 81-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 95-rotated3-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 93-rotated2-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 191.jpg, skipping generation.
# Mask already exists for 84-rotated2-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 92-rotated2-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 90-rotated3-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 85 (1).jpg, skipping generation.
# Mask already exists for 96 (1).jpg, skipping generation.
# Mask already exists for 94-rotated1-rotated3-rotated1.jpg, skipping generation.
# Mask already exists for 94-rotated1-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 89-rotated1-rotated3-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 00233.png, skipping generation.
# Mask already exists for 85-rotated2.jpg, skipping generation.
# Mask already exists for 7-rotated1-rotated1.jpg, skipping generation.
# Mask already exists for 83-rotated2-rotated1.jpg, skipping generation.
# Mask already exists for 92-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 91-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 84-rotated3-rotated2 (1).jpg, skipping generation.
# Processing fractured images:   2%|▏         | 98/4602 [00:00<00:18, 239.40it/s]
# Mask already exists for 82-rotated3-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 1-rotated3-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 2-rotated3-rotated2-rotated1.jpg, skipping generation.
# Mask already exists for 161.jpg, skipping generation.
# Mask already exists for 84-rotated2-rotated2-rotated3 (1).jpg, skipping generation.
# Mask already exists for 98-rotated3-rotated3.jpg, skipping generation.
# Mask already exists for 6-rotated1-rotated1-rotated1.jpg, skipping generation.
# Mask already exists for 99-rotated1-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 80-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 99-rotated1-rotated1.jpg, skipping generation.
# Mask already exists for 83-rotated2-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 84-rotated2-rotated1.jpg, skipping generation.
# Mask already exists for 85-rotated3-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 99-rotated1-rotated2-rotated3 (1).jpg, skipping generation.
# Mask already exists for 94-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 9-rotated1-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 79-rotated2-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 90-rotated1-rotated3-rotated1.jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 81-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 82-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 8-rotated1-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for Transverse-fracture_Q640.jpg, skipping generation.
# Mask already exists for 3-rotated3-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 90-rotated3-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 81-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 5-rotated1-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 89-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 99-rotated3-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 82-rotated1-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 79-rotated2-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 0045.png, skipping generation.
# Mask already exists for 99-rotated3-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 107.jpg, skipping generation.
# Mask already exists for 90-rotated2-rotated2.jpg, skipping generation.
# Mask already exists for 87-rotated2.jpg, skipping generation.
# Mask already exists for 7-rotated2-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 85-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 89-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 85-rotated1-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 83-rotated2-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 93-rotated3-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 8-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 87-rotated1-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 89-rotated2 (1).jpg, skipping generation.
# Mask already exists for 5-rotated1-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 2-rotated2-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 87-rotated2-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 99-rotated1-rotated1-rotated2 - Copy.jpg, skipping generation.
# Processing fractured images:   2%|▏         | 98/4602 [00:00<00:18, 239.40it/s]
# Mask already exists for 113.jpg, skipping generation.
# Mask already exists for 10-1055-b-002-85516_c023_f003-1.jpg, skipping generation.
# Mask already exists for 82-rotated2-rotated3-rotated1.jpg, skipping generation.
# Mask already exists for 81-rotated2-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 96-rotated1-rotated3-rotated1 (1).jpg, skipping generation.
# Mask already exists for 5-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 89-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 9-rotated1-rotated3-rotated1 (1).jpg, skipping generation.
# Mask already exists for 96-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 8-rotated1 (1).jpg, skipping generation.
# Mask already exists for a6980144fa36a4b20737df405b98b51a.jpg, skipping generation.
# Mask already exists for 87-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 3-rotated2-rotated3-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 8-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Processing fractured images:   3%|▎         | 122/4602 [00:00<00:38, 117.45it/s]
# Mask already exists for 8-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 99-rotated2-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 3-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 89-rotated3-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 97-rotated1-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 99-rotated2-rotated1-rotated1.jpg, skipping generation.
# Mask already exists for 50.jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated2-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 5-rotated2-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 89 - Copy (1).jpg, skipping generation.
# Mask already exists for 97-rotated2-rotated3-rotated1 (1).jpg, skipping generation.
# Mask already exists for 82-rotated3-rotated3.jpg, skipping generation.
# Mask already exists for 97-rotated1-rotated2-rotated2 (1).jpg, skipping generation.
# Mask already exists for 90-rotated2-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 94-rotated3-rotated2-rotated3.jpg, skipping generation.
# Processing fractured images:   4%|▎         | 169/4602 [00:01<00:28, 156.48it/s]
# Mask already exists for 86-rotated3-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 3-rotated3-rotated1 (1).jpg, skipping generation.
# Mask already exists for 7-rotated1-rotated1-rotated1.jpg, skipping generation.
# Mask already exists for 7.png, skipping generation.
# Mask already exists for 86-rotated2-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 8-rotated1-rotated3-rotated2.jpg, skipping generation.
# Mask already exists for 4-rotated3.jpg, skipping generation.
# Mask already exists for 86-rotated2-rotated2-rotated3 (1).jpg, skipping generation.
# Mask already exists for 8-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 84.jpg, skipping generation.
# Mask already exists for 80-rotated2-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 84-rotated1-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 2-rotated2-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 89-rotated1-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 87-rotated2-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 3-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 95-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 99-rotated1-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 90-rotated1-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 83-rotated1-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 4-rotated3-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 94-rotated3-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 81-rotated3-rotated2.jpg, skipping generation.
# Mask already exists for gr172.jpg, skipping generation.
# Mask already exists for 7-rotated2-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 6-rotated2-rotated3-rotated1 (1).jpg, skipping generation.
# Mask already exists for 1-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 90-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 1-rotated3-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 9-rotated3-rotated3-rotated2.jpg, skipping generation.
# Mask already exists for c0775e1108f1dd0ff3ada8b4236468_jumbo_-_Copy_jumbo.jpeg, skipping generation.
# Mask already exists for 1-rotated1-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 29(1).jpg, skipping generation.
# Mask already exists for 85-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 87-rotated2-rotated2 (1).jpg, skipping generation.
# Mask already exists for 88-rotated1.jpg, skipping generation.
# Mask already exists for 91 (1).jpg, skipping generation.
# Mask already exists for 83-rotated2-rotated3-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 98-rotated3-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 96-rotated3-rotated3-rotated3.jpg, skipping generation.
# Mask already exists for 2-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 130.jpg, skipping generation.
# Mask already exists for 212.jpg, skipping generation.
# Mask already exists for 87-rotated2-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 90-rotated3-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Processing fractured images:   4%|▍         | 189/4602 [00:01<00:27, 158.51it/s]
# Mask already exists for 2-rotated2-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 93-rotated1-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 6-rotated3-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 79-rotated3-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 80-rotated1-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 80-rotated2 (1).jpg, skipping generation.
# Mask already exists for 99-rotated3-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 93-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 99-rotated2-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 5-rotated1-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 85-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 83-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 2-rotated3-rotated2-rotated2.jpg, skipping generation.
# Mask already exists for 8-rotated2-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 88-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 9-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 99-rotated3-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 91-rotated2.jpg, skipping generation.
# Mask already exists for 87-rotated3-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 9-rotated2-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 4-rotated3-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 1-rotated2-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 86-rotated3-rotated3.jpg, skipping generation.
# Mask already exists for 1-rotated2-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 96-rotated1-rotated1 (1).jpg, skipping generation.
# Mask already exists for 11(1).jpg, skipping generation.
# Mask already exists for 82-rotated3-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 9-rotated1-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for tibia20path20fx.jpg, skipping generation.
# Mask already exists for 84-rotated3-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 5-rotated1-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 98-rotated2-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 81-rotated2-rotated2.jpg, skipping generation.
# Mask already exists for 99-rotated2-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 1-rotated3-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 82-rotated3-rotated3-rotated1 (1).jpg, skipping generation.
# Mask already exists for 1-rotated1 (1).jpg, skipping generation.
# Mask already exists for 140.jpg, skipping generation.
# Mask already exists for 86-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 89-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 218.jpg, skipping generation.
# Mask already exists for 89-rotated3-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 94-rotated1-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 3-rotated3-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for image5.jpeg, skipping generation.
# Mask already exists for 8-rotated1-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 5-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 99-rotated3-rotated2-rotated2.jpg, skipping generation.
# Mask already exists for 86-rotated3-rotated2-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 81-rotated2-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 79-rotated2-rotated2-rotated3 (1).jpg, skipping generation.
# Mask already exists for 97-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 81-rotated2-rotated1-rotated1 (1).jpg, skipping generation.
# Mask already exists for 8-rotated3-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 8-rotated2 (1).jpg, skipping generation.
# Mask already exists for 91-rotated3-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 3-rotated2-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 1-rotated3-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 96-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 80-rotated1-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 2-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 95-rotated1-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 4-rotated1-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 83-rotated1-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 86-rotated3-rotated2-rotated3 (1).jpg, skipping generation.
# Mask already exists for 3-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Processing fractured images:   6%|▌         | 262/4602 [00:01<00:27, 157.58it/s]
# Mask already exists for 2-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 8-rotated2-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 97-rotated1-rotated2-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 51.jpg, skipping generation.
# Mask already exists for 83-rotated1.jpg, skipping generation.
# Mask already exists for 84-rotated3-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 93-rotated1-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 85-rotated3 (1).jpg, skipping generation.
# Mask already exists for 84-rotated2-rotated3-rotated1.jpg, skipping generation.
# Mask already exists for 104.jpg, skipping generation.
# Mask already exists for 9-rotated3-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 90-rotated2-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 96-rotated2-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 81-rotated2-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 4-rotated1-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 1-rotated3-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 8-rotated2-rotated1.jpg, skipping generation.
# Mask already exists for 6-rotated3-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 92-rotated1-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 72c9b4c7b122501e57f63da52f0e1e_gallery (1).jpeg, skipping generation.
# Mask already exists for 2d59fd50936098df8ddf49c912e70b_gallery (2).jpg, skipping generation.
# Mask already exists for 93-rotated1-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 8-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 7-rotated3-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 90-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 83-rotated1-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 89-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 92-rotated3-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for image11 (1).jpeg, skipping generation.
# Mask already exists for 6-rotated2-rotated2-rotated1 (1).jpg, skipping generation.
# Mask already exists for 4-rotated3-rotated2-rotated2.jpg, skipping generation.
# Mask already exists for 89-rotated1-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 98-rotated3-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 96-rotated3-rotated3-rotated2.jpg, skipping generation.
# Processing fractured images:   6%|▋         | 296/4602 [00:01<00:27, 158.73it/s]
# Mask already exists for 86-rotated2-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 83-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 90-rotated3 (1).jpg, skipping generation.
# Mask already exists for 5-rotated2-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 98-rotated3-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 3-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 87da0f2547dc990c9ec77ad8fc5203_gallery.JPEG.jpg, skipping generation.
# Mask already exists for 9-rotated1-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 87-rotated3.jpg, skipping generation.
# Mask already exists for 96-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 93 - Copy (1).jpg, skipping generation.
# Mask already exists for 92-rotated2-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 146.jpg, skipping generation.
# Mask already exists for 87-rotated2-rotated2-rotated1 (1).jpg, skipping generation.
# Mask already exists for 97-rotated2-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 7-rotated2-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 84-rotated2-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 81-rotated2-rotated1-rotated1.jpg, skipping generation.
# Mask already exists for 1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 82-rotated2-rotated3-rotated1 (1).jpg, skipping generation.
# Mask already exists for 85-rotated2-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 90-rotated1-rotated2-rotated1.jpg, skipping generation.
# Mask already exists for 96-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 87-rotated1-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 89-rotated1-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 9-rotated2-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 6-rotated1-rotated2-rotated2.jpg, skipping generation.
# Mask already exists for 87-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 98-rotated3-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 92-rotated3-rotated2-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 90-rotated1-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 99-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 88-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 92-rotated2-rotated2-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 92-rotated2-rotated2-rotated1.jpg, skipping generation.
# Mask already exists for 81-rotated1-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 6-rotated3-rotated1 (1).jpg, skipping generation.
# Mask already exists for 90-rotated3-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 97-rotated3-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 6-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for IMG0002373.jpg, skipping generation.
# Mask already exists for 82-rotated3-rotated3-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 79-rotated2-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 93-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 99-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 2-rotated3-rotated2-rotated2 (1).jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated2-rotated1 (1).jpg, skipping generation.
# Mask already exists for 95-rotated3-rotated3-rotated1.jpg, skipping generation.
# Mask already exists for 6-rotated3-rotated2.jpg, skipping generation.
# Mask already exists for 83-rotated2-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 7-rotated2-rotated1.jpg, skipping generation.
# Mask already exists for 85-rotated1-rotated3-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 40.jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated3-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 89-rotated2-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 6-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 87-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 97-rotated2-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 5-rotated2-rotated3-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 94-rotated2-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 9-rotated2-rotated1-rotated1 (1).jpg, skipping generation.
# Mask already exists for 96-rotated1-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 4-rotated1-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 1-rotated1-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 91-rotated3-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 97-rotated3-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 83-rotated3-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 83-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 187.jpg, skipping generation.
# Mask already exists for 86-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 82-rotated1-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 94-rotated1-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 183.jpg, skipping generation.
# Mask already exists for 1-rotated1-rotated1 (1).jpg, skipping generation.
# Mask already exists for 84-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 82 (1).jpg, skipping generation.
# Mask already exists for 4-rotated2-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 90-rotated3-rotated2-rotated2 (1).jpg, skipping generation.
# Mask already exists for 80-rotated2-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 94-rotated2-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 2-rotated3-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 91-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 92-rotated2-rotated3-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 9-rotated2-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 96-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 84 (1).jpg, skipping generation.
# Mask already exists for 87-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 99-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 173.jpg, skipping generation.
# Mask already exists for 82-rotated2-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 5-rotated1-rotated2-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 84-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 87-rotated1-rotated1 (1).jpg, skipping generation.
# Mask already exists for 85-rotated1-rotated2-rotated3 (1).jpg, skipping generation.
# Mask already exists for 99 - Copy.jpg, skipping generation.
# Mask already exists for 94-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 95-rotated3-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 9-rotated1-rotated3-rotated2.jpg, skipping generation.
# Processing fractured images:   9%|▊         | 398/4602 [00:02<00:25, 164.68it/s]
# Mask already exists for 94-rotated3-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 1-rotated3-rotated3-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 9-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 96-rotated3-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 68.jpg, skipping generation.
# Mask already exists for 90-rotated2-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 4-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 79-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 4-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 90-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 4-rotated2-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 88-rotated3-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 6-rotated2-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 965bde10687811ecbbeb050932094b9f-Figure-1 (1).png, skipping generation.
# Mask already exists for 98-rotated3-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 82-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 86-rotated3-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 96-rotated1-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 86 (1).jpg, skipping generation.
# Mask already exists for 80-rotated2-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 3-rotated2-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 88-rotated2-rotated3-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 98-rotated3-rotated2-rotated3 (1).jpg, skipping generation.
# Mask already exists for 5-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 2-rotated1-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for IMG0002370.jpg, skipping generation.
# Mask already exists for 93-rotated2-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 89-rotated3-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 92-rotated2.jpg, skipping generation.
# Processing fractured images:   9%|▊         | 398/4602 [00:02<00:25, 164.68it/s]
# Mask already exists for 86-rotated3 (1).jpg, skipping generation.
# Mask already exists for 4-rotated1-rotated1-rotated2 (1).jpg, skipping generation.
# Mask already exists for 9-rotated1-rotated1-rotated1.jpg, skipping generation.
# Processing fractured images:   9%|▉         | 415/4602 [00:02<00:48, 85.87it/s]
# Mask already exists for 7-rotated2-rotated2-rotated3 (1).jpg, skipping generation.
# Mask already exists for 99-rotated1-rotated2-rotated2 (1).jpg, skipping generation.
# Mask already exists for 99-rotated2-rotated2-rotated1.jpg, skipping generation.
# Mask already exists for 95-rotated3-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 86-rotated1-rotated3-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 89-rotated2-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 95-rotated1-rotated2-rotated1 (1).jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated3-rotated1.jpg, skipping generation.
# Mask already exists for 85-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 83-rotated2-rotated2-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 83-rotated3-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 99-rotated1-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 6-rotated1-rotated3-rotated2.jpg, skipping generation.
# Mask already exists for 84-rotated3.jpg, skipping generation.
# Mask already exists for 82-rotated3-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 6-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 93-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 5-rotated2-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 93-rotated1-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Processing fractured images:  10%|▉         | 448/4602 [00:03<00:37, 112.08it/s]
# Mask already exists for 83 - Copy (1).jpg, skipping generation.
# Mask already exists for 96 - Copy (1).jpg, skipping generation.
# Mask already exists for 7-rotated1-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 85-rotated2-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 8-rotated1-rotated2-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 6-rotated2 (1).jpg, skipping generation.
# Mask already exists for 82-rotated3-rotated3-rotated1.jpg, skipping generation.
# Mask already exists for 98-rotated2-rotated3-rotated3.jpg, skipping generation.
# Mask already exists for 82-rotated2-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 1-rotated2.jpg, skipping generation.
# Mask already exists for 6-rotated3-rotated2-rotated2.jpg, skipping generation.
# Mask already exists for 91-rotated2-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 9-rotated1-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 92-rotated3-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 90-rotated1-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 98-rotated3-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 97-rotated1-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 8-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 86-rotated2-rotated2-rotated1.jpg, skipping generation.
# Mask already exists for 80-rotated2-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 94-rotated2-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 83-rotated2-rotated2-rotated1.jpg, skipping generation.
# Mask already exists for 93-rotated2-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 80-rotated3-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 82-rotated2-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 88-rotated1-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 92-rotated2-rotated2-rotated2 (1).jpg, skipping generation.
# Mask already exists for 91-rotated2-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 9-rotated1-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 8-rotated3-rotated2-rotated3 (1).jpg, skipping generation.
# Mask already exists for 2-rotated3.jpg, skipping generation.
# Mask already exists for 97-rotated1-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for X-rays.jpg, skipping generation.
# Mask already exists for 7-rotated2-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 94-rotated1-rotated3 (1).jpg, skipping generation.
# Processing fractured images:  10%|█         | 482/4602 [00:03<00:30, 133.71it/s]
# Mask already exists for 5 - Copy.jpg, skipping generation.
# Mask already exists for 89-rotated3-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 91-rotated3-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 154.jpg, skipping generation.
# Mask already exists for 96-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 95-rotated1-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 93-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 92-rotated2 (1).jpg, skipping generation.
# Mask already exists for 90-rotated3-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 96-rotated2-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 82-rotated3-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 4-rotated3-rotated3-rotated3.jpg, skipping generation.
# Mask already exists for 4-rotated3-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 94-rotated2-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 6.jpg, skipping generation.
# Mask already exists for 95-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 3-rotated2-rotated3-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 88-rotated2-rotated2 (1).jpg, skipping generation.
# Mask already exists for 4-rotated2-rotated1 (1).jpg, skipping generation.
# Mask already exists for 97-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 79-rotated2-rotated1 (1).jpg, skipping generation.
# Mask already exists for 89-rotated2-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for leg-xray-showing-closed-spiral-260nw-1586443063.jpg, skipping generation.
# Mask already exists for 3-rotated3-rotated3-rotated3.jpg, skipping generation.
# Mask already exists for 84-rotated1-rotated3-rotated1 (1).jpg, skipping generation.
# Mask already exists for 86-rotated2-rotated2.jpg, skipping generation.
# Mask already exists for 97-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 7-rotated1-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 7-rotated1-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 94-rotated1-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 81-rotated2-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 6-rotated2-rotated1 (1).jpg, skipping generation.
# Mask already exists for 3-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 7-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 214.jpg, skipping generation.
# Processing fractured images:  11%|█         | 516/4602 [00:03<00:27, 146.66it/s]
# Mask already exists for 99-rotated2-rotated2-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 98-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 88-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 94-rotated1-rotated1.jpg, skipping generation.
# Mask already exists for 223.jpg, skipping generation.
# Mask already exists for 5-rotated3-rotated1-rotated1 (1).jpg, skipping generation.
# Mask already exists for 98-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 1-rotated2-rotated3-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 95-rotated2-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 88-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 8-rotated3-rotated2-rotated2 (1).jpg, skipping generation.
# Mask already exists for 92-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 94-rotated2-rotated2-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 2-rotated1-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 0085.png, skipping generation.
# Mask already exists for 94-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 94-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 84-rotated3-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 96-rotated1-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 2-rotated1-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 87-rotated3-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 89-rotated3-rotated2-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 82-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 89-rotated1-rotated1.jpg, skipping generation.
# Mask already exists for 87-rotated3-rotated3-rotated3.jpg, skipping generation.
# Mask already exists for 79-rotated3-rotated3-rotated1.jpg, skipping generation.
# Mask already exists for 98-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 85-rotated2-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 91-rotated1-rotated3-rotated2 (1).jpg, skipping generation.
# Mask already exists for 96-rotated3-rotated2-rotated3.jpg, skipping generation.
# Mask already exists for 91-rotated3-rotated3-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 94-rotated2-rotated2-rotated2.jpg, skipping generation.
# Mask already exists for 85-rotated3-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 87-rotated1-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 4-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 99-rotated1-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 99-rotated1 (1).jpg, skipping generation.
# Mask already exists for 7-rotated1-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 9-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 88-rotated1-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 1b62e6fbfbc5a2f70c6af413189cfc82.jpg, skipping generation.
# Mask already exists for 94-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 93-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 8-rotated1-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 83-rotated3-rotated2-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 97-rotated1-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 9-rotated3-rotated3-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 3-rotated2-rotated2-rotated1.jpg, skipping generation.
# Mask already exists for 86-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 87-rotated1-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 97-rotated3-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 5-rotated1-rotated1-rotated3 (1).jpg, skipping generation.
# Mask already exists for 15(1).jpg, skipping generation.
# Mask already exists for 81-rotated3-rotated2-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 91-rotated2-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 3-rotated3-rotated3-rotated1.jpg, skipping generation.
# Mask already exists for 22(1).jpg, skipping generation.
# Mask already exists for 1b.jpg, skipping generation.
# Mask already exists for 92-rotated3-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 4-rotated3-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 82-rotated2-rotated2-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 81-rotated2-rotated1-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 9-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 7-rotated2-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 4-rotated2-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 99-rotated1-rotated2-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 43.jpg, skipping generation.
# Mask already exists for 80-rotated1-rotated1-rotated2 - Copy.jpg, skipping generation.
# Mask already exists for 9-rotated3-rotated2-rotated2 (1).jpg, skipping generation.
# Mask already exists for 83-rotated1-rotated2-rotated3 (1).jpg, skipping generation.
# Mask already exists for 9-rotated2-rotated1-rotated1.jpg, skipping generation.
# Processing fractured images:  13%|█▎        | 588/4602 [00:03<00:23, 169.07it/s]
# Mask already exists for 88-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 7-rotated3-rotated1 (1).jpg, skipping generation.
# Mask already exists for 80-rotated1-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 5-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 93-rotated2-rotated3-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 6-rotated2-rotated1-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 93-rotated1 (1).jpg, skipping generation.
# Mask already exists for 97-rotated3-rotated1-rotated1.jpg, skipping generation.
# Mask already exists for 97-rotated1-rotated3-rotated3 (1).jpg, skipping generation.
# Mask already exists for 85-rotated3-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 7-rotated1-rotated1-rotated3.jpg, skipping generation.
# Mask already exists for 98-rotated2-rotated2-rotated3 (1).jpg, skipping generation.
# Mask already exists for 95-rotated1-rotated3-rotated2 - Copy (1).jpg, skipping generation.
# Mask already exists for 98-rotated2-rotated2-rotated1 (1).jpg, skipping generation.
# Mask already exists for 3-rotated2-rotated1-rotated3 - Copy (1).jpg, skipping generation.
# Mask already exists for 9-rotated1-rotated2-rotated1 - Copy.jpg, skipping generation.
# Mask already exists for 9-rotated3-rotated1-rotated2.jpg, skipping generation.
# Mask already exists for 97-rotated1-rotated2-rotated1 - Copy (1).jpg, skipping generation.
# Mask already exists for 90-rotated2-rotated2-rotated2 (1).jpg, skipping generation.
# Mask already exists for 38(1).jpg, skipping generation.
# Mask already exists for 4-rotated3-rotated1-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 89-rotated2-rotated3-rotated3 - Copy.jpg, skipping generation.
# Mask already exists for 86-rotated3-rotated2-rotated3.jpg, skipping generation.
# ...
# Processing not fractured images:  57%|█████▋    | 152/268 [00:36<00:31,  3.71it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  57%|█████▋    | 153/268 [00:37<00:36,  3.13it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  57%|█████▋    | 154/268 [00:37<00:32,  3.53it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  58%|█████▊    | 155/268 [00:37<00:36,  3.08it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  58%|█████▊    | 156/268 [00:37<00:31,  3.51it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  59%|█████▊    | 157/268 [00:38<00:28,  3.88it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  59%|█████▉    | 158/268 [00:38<00:26,  4.17it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  59%|█████▉    | 159/268 [00:38<00:24,  4.40it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  60%|█████▉    | 160/268 [00:38<00:26,  4.09it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  60%|██████    | 161/268 [00:38<00:24,  4.33it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  60%|██████    | 162/268 [00:39<00:23,  4.46it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  61%|██████    | 163/268 [00:39<00:23,  4.40it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  61%|██████    | 164/268 [00:39<00:23,  4.42it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  62%|██████▏   | 165/268 [00:39<00:23,  4.42it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  62%|██████▏   | 166/268 [00:40<00:23,  4.38it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  62%|██████▏   | 167/268 [00:40<00:24,  4.08it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  63%|██████▎   | 168/268 [00:40<00:23,  4.17it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  63%|██████▎   | 169/268 [00:40<00:26,  3.71it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  63%|██████▎   | 170/268 [00:41<00:24,  3.94it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  64%|██████▍   | 171/268 [00:41<00:23,  4.04it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  64%|██████▍   | 172/268 [00:41<00:22,  4.21it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  65%|██████▍   | 173/268 [00:41<00:22,  4.32it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  65%|██████▍   | 174/268 [00:42<00:22,  4.18it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  65%|██████▌   | 175/268 [00:42<00:21,  4.23it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  66%|██████▌   | 176/268 [00:42<00:22,  4.14it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  66%|██████▌   | 177/268 [00:42<00:21,  4.32it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  66%|██████▋   | 178/268 [00:43<00:20,  4.41it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  67%|██████▋   | 179/268 [00:43<00:24,  3.62it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  67%|██████▋   | 180/268 [00:43<00:24,  3.58it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  68%|██████▊   | 181/268 [00:43<00:22,  3.93it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  68%|██████▊   | 182/268 [00:44<00:25,  3.40it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  68%|██████▊   | 183/268 [00:44<00:22,  3.79it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  69%|██████▊   | 184/268 [00:44<00:26,  3.19it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  69%|██████▉   | 185/268 [00:45<00:23,  3.54it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  69%|██████▉   | 186/268 [00:45<00:23,  3.45it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  70%|██████▉   | 187/268 [00:45<00:21,  3.75it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  70%|███████   | 188/268 [00:45<00:19,  4.08it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  71%|███████   | 189/268 [00:46<00:21,  3.74it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  71%|███████   | 190/268 [00:46<00:19,  4.09it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  71%|███████▏  | 191/268 [00:46<00:17,  4.33it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  72%|███████▏  | 193/268 [00:46<00:12,  5.87it/s]
# Skipping /content/Bone_Fracture_Binary_Classification1/Bone_Fracture_Binary_Classification1/test/not fractured/IMG0004143.jpg due to error: image file is truncated (10 bytes not processed)
# `label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  72%|███████▏  | 194/268 [00:46<00:13,  5.66it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  73%|███████▎  | 195/268 [00:47<00:17,  4.20it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  73%|███████▎  | 196/268 [00:47<00:16,  4.43it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  74%|███████▎  | 197/268 [00:47<00:15,  4.63it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  74%|███████▍  | 198/268 [00:47<00:14,  4.78it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  74%|███████▍  | 199/268 [00:48<00:14,  4.82it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  75%|███████▍  | 200/268 [00:48<00:14,  4.85it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  75%|███████▌  | 201/268 [00:48<00:13,  4.85it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  75%|███████▌  | 202/268 [00:48<00:13,  4.93it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  76%|███████▌  | 203/268 [00:48<00:13,  4.67it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  76%|███████▌  | 204/268 [00:49<00:13,  4.74it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  76%|███████▋  | 205/268 [00:49<00:17,  3.54it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  77%|███████▋  | 206/268 [00:49<00:17,  3.64it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  77%|███████▋  | 207/268 [00:50<00:15,  3.97it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  78%|███████▊  | 208/268 [00:50<00:14,  4.26it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  78%|███████▊  | 209/268 [00:50<00:13,  4.50it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  78%|███████▊  | 210/268 [00:50<00:13,  4.45it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  79%|███████▊  | 211/268 [00:50<00:12,  4.56it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  79%|███████▉  | 212/268 [00:51<00:11,  4.71it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  79%|███████▉  | 213/268 [00:51<00:11,  4.82it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  80%|███████▉  | 214/268 [00:51<00:12,  4.48it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  80%|████████  | 215/268 [00:51<00:11,  4.69it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  81%|████████  | 216/268 [00:51<00:10,  4.77it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  81%|████████  | 217/268 [00:52<00:10,  4.84it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  81%|████████▏ | 218/268 [00:52<00:10,  4.89it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  82%|████████▏ | 219/268 [00:52<00:09,  4.96it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  82%|████████▏ | 220/268 [00:52<00:09,  5.04it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  82%|████████▏ | 221/268 [00:52<00:09,  5.03it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  83%|████████▎ | 222/268 [00:53<00:09,  5.08it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  83%|████████▎ | 223/268 [00:53<00:08,  5.03it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  84%|████████▎ | 224/268 [00:53<00:09,  4.70it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  84%|████████▍ | 225/268 [00:53<00:09,  4.62it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  84%|████████▍ | 226/268 [00:54<00:09,  4.31it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  85%|████████▍ | 227/268 [00:54<00:09,  4.34it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  85%|████████▌ | 228/268 [00:54<00:08,  4.50it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  85%|████████▌ | 229/268 [00:54<00:08,  4.57it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  86%|████████▌ | 230/268 [00:54<00:08,  4.23it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  86%|████████▌ | 231/268 [00:55<00:08,  4.28it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  87%|████████▋ | 232/268 [00:55<00:08,  4.44it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  87%|████████▋ | 233/268 [00:55<00:11,  3.08it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  87%|████████▋ | 234/268 [00:56<00:09,  3.43it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  88%|████████▊ | 235/268 [00:56<00:09,  3.66it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  88%|████████▊ | 236/268 [00:56<00:08,  3.75it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  88%|████████▊ | 237/268 [00:56<00:07,  3.93it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  89%|████████▉ | 238/268 [00:57<00:07,  3.97it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  89%|████████▉ | 239/268 [00:57<00:07,  3.95it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  90%|████████▉ | 240/268 [00:57<00:06,  4.17it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  90%|████████▉ | 241/268 [00:57<00:06,  4.27it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  90%|█████████ | 242/268 [00:58<00:06,  4.03it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  91%|█████████ | 243/268 [00:58<00:05,  4.27it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  91%|█████████ | 244/268 [00:58<00:05,  4.47it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  91%|█████████▏| 245/268 [00:58<00:04,  4.67it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  92%|█████████▏| 246/268 [00:58<00:04,  4.79it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  92%|█████████▏| 247/268 [00:59<00:04,  4.77it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  93%|█████████▎| 248/268 [00:59<00:04,  4.74it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  93%|█████████▎| 249/268 [00:59<00:03,  4.87it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  93%|█████████▎| 250/268 [00:59<00:04,  3.96it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  94%|█████████▎| 251/268 [01:00<00:04,  4.17it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  94%|█████████▍| 252/268 [01:00<00:04,  3.29it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  94%|█████████▍| 253/268 [01:00<00:04,  3.69it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  95%|█████████▍| 254/268 [01:00<00:03,  4.04it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  95%|█████████▌| 255/268 [01:01<00:03,  4.31it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  96%|█████████▌| 256/268 [01:01<00:02,  4.38it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  96%|█████████▌| 257/268 [01:01<00:02,  4.50it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  96%|█████████▋| 258/268 [01:01<00:02,  4.68it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  97%|█████████▋| 259/268 [01:02<00:02,  3.67it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  97%|█████████▋| 260/268 [01:02<00:02,  3.98it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  97%|█████████▋| 261/268 [01:02<00:02,  3.29it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  98%|█████████▊| 262/268 [01:02<00:01,  3.69it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  98%|█████████▊| 263/268 [01:03<00:01,  3.15it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  99%|█████████▊| 264/268 [01:03<00:01,  3.50it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  99%|█████████▉| 265/268 [01:03<00:00,  3.88it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images:  99%|█████████▉| 266/268 [01:03<00:00,  4.17it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images: 100%|█████████▉| 267/268 [01:04<00:00,  3.27it/s]`label_ids_to_fuse` unset. No instance will be fused.
# Processing not fractured images: 100%|██████████| 268/268 [01:04<00:00,  4.14it/s]
# Mask generation complete.

# %% [markdown]
# ### Deleting unwanted images

# %%
import os

def get_image_files(directory):
    """Return a set of image file names in the given directory and its subdirectories."""
    image_files = set()
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.tiff')):
                relative_path = os.path.relpath(os.path.join(root, file), directory)
                image_files.add(relative_path)
    return image_files

def delete_extra_images(base_dir, reference_dir):
    """Delete images in base_dir that are not present in reference_dir."""
    base_images = get_image_files(base_dir)
    reference_images = get_image_files(reference_dir)

    extra_images = base_images - reference_images

    for image in extra_images:
        image_path = os.path.join(base_dir, image)
        if os.path.exists(image_path):
            print(f"Deleting {image_path}")
            os.remove(image_path)

# Directories
base_directory = 'Bone_Fracture_Binary_Classification1'
reference_directory = 'Bone_Fracture_dataset_mask'

# Perform the deletion
delete_extra_images(base_directory, reference_directory)
# Out:
# Deleting Bone_Fracture_Binary_Classification1\test\not fractured\IMG0004134.jpg
# Deleting Bone_Fracture_Binary_Classification1\val\not fractured\IMG0004149.jpg
# Deleting Bone_Fracture_Binary_Classification1\train\not fractured\IMG0004347.jpg
# Deleting Bone_Fracture_Binary_Classification1\train\not fractured\IMG0004149.jpg
# Deleting Bone_Fracture_Binary_Classification1\val\not fractured\IMG0004148.jpg
# Deleting Bone_Fracture_Binary_Classification1\train\not fractured\IMG0004148.jpg
# Deleting Bone_Fracture_Binary_Classification1\test\not fractured\IMG0004347.jpg
# Deleting Bone_Fracture_Binary_Classification1\test\not fractured\IMG0004143.jpg
# Deleting Bone_Fracture_Binary_Classification1\val\not fractured\IMG0004143.jpg
# Deleting Bone_Fracture_Binary_Classification1\train\not fractured\IMG0004308.jpg
# Deleting Bone_Fracture_Binary_Classification1\val\not fractured\IMG0004347.jpg
# Deleting Bone_Fracture_Binary_Classification1\test\not fractured\IMG0004148.jpg
# Deleting Bone_Fracture_Binary_Classification1\train\not fractured\IMG0004134.jpg
# Deleting Bone_Fracture_Binary_Classification1\val\not fractured\IMG0004308.jpg
# Deleting Bone_Fracture_Binary_Classification1\train\not fractured\IMG0004143.jpg
# Deleting Bone_Fracture_Binary_Classification1\test\not fractured\IMG0004308.jpg
# Deleting Bone_Fracture_Binary_Classification1\val\not fractured\IMG0004134.jpg
# Deleting Bone_Fracture_Binary_Classification1\test\not fractured\IMG0004149.jpg

# %%
import os
from PIL import Image, ImageFile
import warnings
warnings.filterwarnings("ignore")
ImageFile.LOAD_TRUNCATED_IMAGES = True

def safe_load_img(path, target_size=None):
    try:
        img = Image.open(path).convert('RGB')
        if target_size:
            img = img.resize(target_size, Image.ANTIALIAS)
        return img
    except (OSError, IOError) as e:
        print(f"Error loading image {path}: {e}")
        return None

def delete_corresponding_images(image_dir, mask_dir):
    for root, _, files in os.walk(image_dir):
        for img_filename in files:
            img_path = os.path.join(root, img_filename)
            mask_path = img_path.replace(image_dir, mask_dir)
            
            if not os.path.isfile(mask_path):
                print(f"Corresponding mask for image {img_filename} not found in {mask_path}. Skipping.")
                continue
            
            if safe_load_img(img_path) is None:
                print(f"Deleting corrupted image and mask: {img_path}, {mask_path}")
                os.remove(img_path)
                os.remove(mask_path)

def process_image_and_mask_dirs(base_image_dir, base_mask_dir):
    for subdir in ['train', 'val', 'test']:
        for category in ['fractured', 'not fractured']:
            image_dir = os.path.join(base_image_dir, subdir, category)
            mask_dir = os.path.join(base_mask_dir, subdir, category)
            if os.path.isdir(image_dir) and os.path.isdir(mask_dir):
                print(f"Processing {image_dir} and {mask_dir}")
                delete_corresponding_images(image_dir, mask_dir)

base_image_dir = './Bone_Fracture_Binary_Classification1'
base_mask_dir = './Bone_Fracture_dataset_mask'

process_image_and_mask_dirs(base_image_dir, base_mask_dir)
# Out:
# Processing ./Bone_Fracture_Binary_Classification1\train\fractured and ./Bone_Fracture_dataset_mask\train\fractured
# Processing ./Bone_Fracture_Binary_Classification1\train\not fractured and ./Bone_Fracture_dataset_mask\train\not fractured
# Processing ./Bone_Fracture_Binary_Classification1\val\fractured and ./Bone_Fracture_dataset_mask\val\fractured
# Processing ./Bone_Fracture_Binary_Classification1\val\not fractured and ./Bone_Fracture_dataset_mask\val\not fractured
# Processing ./Bone_Fracture_Binary_Classification1\test\fractured and ./Bone_Fracture_dataset_mask\test\fractured
# Processing ./Bone_Fracture_Binary_Classification1\test\not fractured and ./Bone_Fracture_dataset_mask\test\not fractured
